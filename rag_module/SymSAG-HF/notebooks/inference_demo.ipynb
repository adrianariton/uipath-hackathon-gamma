# %% [markdown]
# # SymSAG-HF Inference Demo
# This notebook outlines how to load a pretrained SymSAG-HF checkpoint, index the graph, and run RAG queries. Replace placeholder paths with your checkpoints.

# %%
from symsag_hf import SymSAGModel, SymSAGRAGPipeline
model = SymSAGModel.from_pretrained('outputs/demo')
pipeline = SymSAGRAGPipeline(model, top_k=3)
pipeline.index_graph()
pipeline.answer('What is the area of a 2x3 rectangle?')
